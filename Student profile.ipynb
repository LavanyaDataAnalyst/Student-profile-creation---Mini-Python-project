# %%
Student_Name = input('Enter your name:')
Age = input('Enter your age: ')
Favourite_Subjects = input('Enter your Favourite subjects: ')
# Out:
# Enter your name:Lavanya
# Enter your age: 27
# Enter your Favourite subjects: Excel, PowerBI

# %%
print('\nStudent Profile')
print(f'\nName: {Student_Name}\nAge: {Age}\nFavourite subjects: {Favourite_Subjects}')
print('\nUpdated Profile')
updated_subjects= input('\nadd your favourite subjects: ')
print(f'Updated subjects: {updated_subjects}, {Favourite_Subjects}')
# Out:
# Student Profile
#
# Name: Lavanya
# Age: 27
# Favourite subjects: Excel, PowerBI
#
# Updated Profile
#
# add your favourite subjects: SQL, Python
# Updated subjects: SQL, Python, Excel, PowerBI
